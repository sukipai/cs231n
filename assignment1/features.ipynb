# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

# num_color_bins = 10 # Number of bins in the color histogram
num_color_bins = 25 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train Softmax classifier on features
# Using the Softmax code developed earlier in the assignment, train Softmax classifiers on top of the features extracted above; this should achieve better results than training them directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import Softmax

learning_rates = [1e-7, 1e-6]
regularization_strengths = [5e5, 5e6]

results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the Softmax; save#
# the best trained classifer in best_softmax. If you carefully tune the model, #
# you should be able to get accuracy of above 0.42 on the validation set.      #
################################################################################
# 使用嵌套循环遍历所有超参数组合，进行网格搜索
for lr in learning_rates:
    for reg in regularization_strengths:
        # 1. 初始化 Softmax 分类器实例
        softmax = Softmax()

        # 2. 训练分类器
        # 使用训练数据 X_train_feats 和 y_train
        # 这里我们假设训练迭代次数为1500次，可以根据需要调整
        softmax.train(X_train_feats, y_train, learning_rate=lr, reg=reg,
                      num_iters=1000, verbose=False)

        # 3. 在训练集和验证集上进行预测
        y_train_pred = softmax.predict(X_train_feats)
        y_val_pred = softmax.predict(X_val_feats)

        # 4. 计算训练集和验证集的准确率
        train_accuracy = np.mean(y_train == y_train_pred)
        val_accuracy = np.mean(y_val == y_val_pred)

        # 5. 存储结果
        results[(lr, reg)] = (train_accuracy, val_accuracy)

        # 6. 检查并保存最佳模型
        # 如果当前组合的验证集准确率超过了之前的最佳值
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = softmax # 保存这个训练好的分类器对象

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved: %f' % best_val)
# Out:
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.419755 val accuracy: 0.421000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.313041 val accuracy: 0.336000
# lr 1.000000e-06 reg 5.000000e+05 train accuracy: 0.310184 val accuracy: 0.302000
# lr 1.000000e-06 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved: 0.421000

# %%
# Evaluate your trained Softmax on the test set: you should be able to get at least 0.42
y_test_pred = best_softmax.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.424

# %%
# Save best softmax model
best_softmax.save("best_softmax_features.npy")
# Out:
# best_softmax_features.npy saved.

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 170)
# (49000, 169)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats,
    'y_train': y_train,
    'X_val': X_val_feats,
    'y_val': y_val,
    'X_test': X_test_feats,
    'y_test': y_test,
}

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None
best_acc = 0.0

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# 定义你想要尝试的超参数范围
learning_rates = [5e-1, 1e-1, 1]
regularization_strengths = [1e-3, 3e-3, 5e-3]

# 使用嵌套循环进行网格搜索
for lr in learning_rates:
    for reg in regularization_strengths:
            # 1. 初始化一个新的网络实例
            net = TwoLayerNet(input_dim, 200, num_classes, reg=reg)

            # 2. 初始化一个新的 Solver 实例
            solver = Solver(net, data,
                            update_rule='sgd',
                            optim_config={
                                'learning_rate': lr,
                            },
                            lr_decay=0.95,
                            num_epochs=10, 
                            batch_size=200,
                            print_every=100)

            # 3. 运行训练
            solver.train()

            # 获取当前模型的验证集准确率
            val_acc = solver.best_val_acc
            
            # 打印当前组合的结果
            print(f'lr {lr}, reg {reg}, -> val_acc: {val_acc}')

            # 4. 检查并保存最佳模型
            if val_acc > best_acc:
                best_acc = val_acc
                best_net = net

# 打印出最佳结果
print(f'Best validation accuracy achieved: {best_acc}')
# Out:
# (Iteration 1 / 2450) loss: 2.302616
# (Epoch 0 / 10) train acc: 0.104000; val_acc: 0.112000
# (Iteration 101 / 2450) loss: 1.476682
# (Iteration 201 / 2450) loss: 1.341001
# (Epoch 1 / 10) train acc: 0.502000; val_acc: 0.523000
# (Iteration 301 / 2450) loss: 1.327869
# (Iteration 401 / 2450) loss: 1.308027
# (Epoch 2 / 10) train acc: 0.587000; val_acc: 0.547000
# (Iteration 501 / 2450) loss: 1.295121
# (Iteration 601 / 2450) loss: 1.387531
# (Iteration 701 / 2450) loss: 1.178970
# (Epoch 3 / 10) train acc: 0.629000; val_acc: 0.581000
# (Iteration 801 / 2450) loss: 1.156305
# (Iteration 901 / 2450) loss: 1.127607
# (Epoch 4 / 10) train acc: 0.624000; val_acc: 0.584000
# (Iteration 1001 / 2450) loss: 1.183578
# (Iteration 1101 / 2450) loss: 1.053122
# (Iteration 1201 / 2450) loss: 1.064776
# (Epoch 5 / 10) train acc: 0.654000; val_acc: 0.575000
# (Iteration 1301 / 2450) loss: 1.100519
# (Iteration 1401 / 2450) loss: 1.106490
# (Epoch 6 / 10) train acc: 0.664000; val_acc: 0.596000
# (Iteration 1501 / 2450) loss: 1.132594
# (Iteration 1601 / 2450) loss: 1.112353
# (Iteration 1701 / 2450) loss: 1.016225
# (Epoch 7 / 10) train acc: 0.690000; val_acc: 0.582000
# (Iteration 1801 / 2450) loss: 1.123728
# (Iteration 1901 / 2450) loss: 1.053318
# (Epoch 8 / 10) train acc: 0.677000; val_acc: 0.593000
# (Iteration 2001 / 2450) loss: 0.969681
# (Iteration 2101 / 2450) loss: 1.020430
# (Iteration 2201 / 2450) loss: 0.987644
# (Epoch 9 / 10) train acc: 0.695000; val_acc: 0.589000
# (Iteration 2301 / 2450) loss: 1.062572
# (Iteration 2401 / 2450) loss: 0.994650
# (Epoch 10 / 10) train acc: 0.699000; val_acc: 0.600000
# lr 0.5, reg 0.001, -> val_acc: 0.6
# (Iteration 1 / 2450) loss: 2.302645
# (Epoch 0 / 10) train acc: 0.120000; val_acc: 0.113000
# (Iteration 101 / 2450) loss: 1.499636
# (Iteration 201 / 2450) loss: 1.499648
# (Epoch 1 / 10) train acc: 0.522000; val_acc: 0.514000
# (Iteration 301 / 2450) loss: 1.327198
# (Iteration 401 / 2450) loss: 1.394487
# (Epoch 2 / 10) train acc: 0.554000; val_acc: 0.555000
# (Iteration 501 / 2450) loss: 1.315253
# (Iteration 601 / 2450) loss: 1.255301
# (Iteration 701 / 2450) loss: 1.264294
# (Epoch 3 / 10) train acc: 0.569000; val_acc: 0.530000
# (Iteration 801 / 2450) loss: 1.218547
# (Iteration 901 / 2450) loss: 1.188153
# (Epoch 4 / 10) train acc: 0.618000; val_acc: 0.563000
# (Iteration 1001 / 2450) loss: 1.146378
# (Iteration 1101 / 2450) loss: 1.194204
# (Iteration 1201 / 2450) loss: 1.311233
# (Epoch 5 / 10) train acc: 0.640000; val_acc: 0.564000
# (Iteration 1301 / 2450) loss: 1.310576
# (Iteration 1401 / 2450) loss: 1.115970
# (Epoch 6 / 10) train acc: 0.629000; val_acc: 0.569000
# (Iteration 1501 / 2450) loss: 1.274747
# (Iteration 1601 / 2450) loss: 1.268541
# (Iteration 1701 / 2450) loss: 1.248920
# (Epoch 7 / 10) train acc: 0.626000; val_acc: 0.583000
# (Iteration 1801 / 2450) loss: 1.262156
# (Iteration 1901 / 2450) loss: 1.193226
# (Epoch 8 / 10) train acc: 0.654000; val_acc: 0.585000
# (Iteration 2001 / 2450) loss: 1.150279
# (Iteration 2101 / 2450) loss: 1.164282
# (Iteration 2201 / 2450) loss: 1.205020
# (Epoch 9 / 10) train acc: 0.670000; val_acc: 0.590000
# (Iteration 2301 / 2450) loss: 1.238443
# (Iteration 2401 / 2450) loss: 1.215150
# (Epoch 10 / 10) train acc: 0.678000; val_acc: 0.585000
# lr 0.5, reg 0.003, -> val_acc: 0.59
# (Iteration 1 / 2450) loss: 2.302672
# (Epoch 0 / 10) train acc: 0.103000; val_acc: 0.098000
# (Iteration 101 / 2450) loss: 1.538377
# (Iteration 201 / 2450) loss: 1.524467
# (Epoch 1 / 10) train acc: 0.537000; val_acc: 0.519000
# (Iteration 301 / 2450) loss: 1.421018
# (Iteration 401 / 2450) loss: 1.341959
# (Epoch 2 / 10) train acc: 0.568000; val_acc: 0.538000
# (Iteration 501 / 2450) loss: 1.222715
# (Iteration 601 / 2450) loss: 1.342964
# (Iteration 701 / 2450) loss: 1.422756
# (Epoch 3 / 10) train acc: 0.578000; val_acc: 0.550000
# (Iteration 801 / 2450) loss: 1.288629
# (Iteration 901 / 2450) loss: 1.407964
# (Epoch 4 / 10) train acc: 0.577000; val_acc: 0.568000
# (Iteration 1001 / 2450) loss: 1.312805
# (Iteration 1101 / 2450) loss: 1.254705
# (Iteration 1201 / 2450) loss: 1.212850
# (Epoch 5 / 10) train acc: 0.587000; val_acc: 0.575000
# (Iteration 1301 / 2450) loss: 1.368604
# (Iteration 1401 / 2450) loss: 1.256023
# (Epoch 6 / 10) train acc: 0.599000; val_acc: 0.561000
# (Iteration 1501 / 2450) loss: 1.295862
# (Iteration 1601 / 2450) loss: 1.409752
# (Iteration 1701 / 2450) loss: 1.287437
# (Epoch 7 / 10) train acc: 0.640000; val_acc: 0.577000
# (Iteration 1801 / 2450) loss: 1.335577
# (Iteration 1901 / 2450) loss: 1.302720
# (Epoch 8 / 10) train acc: 0.634000; val_acc: 0.584000
# (Iteration 2001 / 2450) loss: 1.440439
# (Iteration 2101 / 2450) loss: 1.281436
# (Iteration 2201 / 2450) loss: 1.287471
# (Epoch 9 / 10) train acc: 0.633000; val_acc: 0.593000
# (Iteration 2301 / 2450) loss: 1.198319
# (Iteration 2401 / 2450) loss: 1.271678
# (Epoch 10 / 10) train acc: 0.631000; val_acc: 0.579000
# lr 0.5, reg 0.005, -> val_acc: 0.593
# (Iteration 1 / 2450) loss: 2.302575
# (Epoch 0 / 10) train acc: 0.105000; val_acc: 0.079000
# (Iteration 101 / 2450) loss: 2.265207
# (Iteration 201 / 2450) loss: 1.763827
# (Epoch 1 / 10) train acc: 0.384000; val_acc: 0.392000
# (Iteration 301 / 2450) loss: 1.608105
# (Iteration 401 / 2450) loss: 1.356379
# (Epoch 2 / 10) train acc: 0.487000; val_acc: 0.501000
# (Iteration 501 / 2450) loss: 1.444521
# (Iteration 601 / 2450) loss: 1.329317
# (Iteration 701 / 2450) loss: 1.412101
# (Epoch 3 / 10) train acc: 0.514000; val_acc: 0.505000
# (Iteration 801 / 2450) loss: 1.284166
# (Iteration 901 / 2450) loss: 1.412826
# (Epoch 4 / 10) train acc: 0.541000; val_acc: 0.521000
# (Iteration 1001 / 2450) loss: 1.341771
# (Iteration 1101 / 2450) loss: 1.432658
# (Iteration 1201 / 2450) loss: 1.249549
# (Epoch 5 / 10) train acc: 0.544000; val_acc: 0.526000
# (Iteration 1301 / 2450) loss: 1.517337
# (Iteration 1401 / 2450) loss: 1.295380
# (Epoch 6 / 10) train acc: 0.568000; val_acc: 0.545000
# (Iteration 1501 / 2450) loss: 1.304467
# (Iteration 1601 / 2450) loss: 1.338582
# (Iteration 1701 / 2450) loss: 1.286082
# (Epoch 7 / 10) train acc: 0.530000; val_acc: 0.549000
# (Iteration 1801 / 2450) loss: 1.287707
# (Iteration 1901 / 2450) loss: 1.368013
# (Epoch 8 / 10) train acc: 0.569000; val_acc: 0.556000
# (Iteration 2001 / 2450) loss: 1.265850
# (Iteration 2101 / 2450) loss: 1.249111
# (Iteration 2201 / 2450) loss: 1.233504
# (Epoch 9 / 10) train acc: 0.599000; val_acc: 0.572000
# (Iteration 2301 / 2450) loss: 1.121087
# (Iteration 2401 / 2450) loss: 1.232935
# (Epoch 10 / 10) train acc: 0.580000; val_acc: 0.560000
# lr 0.1, reg 0.001, -> val_acc: 0.572
# (Iteration 1 / 2450) loss: 2.302619
# (Epoch 0 / 10) train acc: 0.096000; val_acc: 0.107000
# (Iteration 101 / 2450) loss: 2.270350
# (Iteration 201 / 2450) loss: 1.811226
# (Epoch 1 / 10) train acc: 0.407000; val_acc: 0.396000
# (Iteration 301 / 2450) loss: 1.553157
# (Iteration 401 / 2450) loss: 1.421261
# (Epoch 2 / 10) train acc: 0.483000; val_acc: 0.504000
# (Iteration 501 / 2450) loss: 1.472776
# (Iteration 601 / 2450) loss: 1.432455
# (Iteration 701 / 2450) loss: 1.346025
# (Epoch 3 / 10) train acc: 0.538000; val_acc: 0.517000
# (Iteration 801 / 2450) loss: 1.498768
# (Iteration 901 / 2450) loss: 1.279244
# (Epoch 4 / 10) train acc: 0.553000; val_acc: 0.520000
# (Iteration 1001 / 2450) loss: 1.362457
# (Iteration 1101 / 2450) loss: 1.371033
# (Iteration 1201 / 2450) loss: 1.275757
# (Epoch 5 / 10) train acc: 0.550000; val_acc: 0.532000
# (Iteration 1301 / 2450) loss: 1.360718
# (Iteration 1401 / 2450) loss: 1.324865
# (Epoch 6 / 10) train acc: 0.528000; val_acc: 0.537000
# (Iteration 1501 / 2450) loss: 1.253271
# (Iteration 1601 / 2450) loss: 1.243404
# (Iteration 1701 / 2450) loss: 1.362347
# (Epoch 7 / 10) train acc: 0.573000; val_acc: 0.530000
# (Iteration 1801 / 2450) loss: 1.261096
# (Iteration 1901 / 2450) loss: 1.362269
# (Epoch 8 / 10) train acc: 0.585000; val_acc: 0.538000
# (Iteration 2001 / 2450) loss: 1.357857
# (Iteration 2101 / 2450) loss: 1.350004
# (Iteration 2201 / 2450) loss: 1.328858
# (Epoch 9 / 10) train acc: 0.544000; val_acc: 0.549000
# (Iteration 2301 / 2450) loss: 1.351003
# (Iteration 2401 / 2450) loss: 1.244964
# (Epoch 10 / 10) train acc: 0.592000; val_acc: 0.545000
# lr 0.1, reg 0.003, -> val_acc: 0.549
# (Iteration 1 / 2450) loss: 2.302655
# (Epoch 0 / 10) train acc: 0.114000; val_acc: 0.128000
# (Iteration 101 / 2450) loss: 2.267871
# (Iteration 201 / 2450) loss: 1.911797
# (Epoch 1 / 10) train acc: 0.370000; val_acc: 0.378000
# (Iteration 301 / 2450) loss: 1.642321
# (Iteration 401 / 2450) loss: 1.469964
# (Epoch 2 / 10) train acc: 0.484000; val_acc: 0.500000
# (Iteration 501 / 2450) loss: 1.458377
# (Iteration 601 / 2450) loss: 1.611983
# (Iteration 701 / 2450) loss: 1.407342
# (Epoch 3 / 10) train acc: 0.517000; val_acc: 0.516000
# (Iteration 801 / 2450) loss: 1.436323
# (Iteration 901 / 2450) loss: 1.349542
# (Epoch 4 / 10) train acc: 0.518000; val_acc: 0.520000
# (Iteration 1001 / 2450) loss: 1.321790
# (Iteration 1101 / 2450) loss: 1.363838
# (Iteration 1201 / 2450) loss: 1.343522
# (Epoch 5 / 10) train acc: 0.550000; val_acc: 0.527000
# (Iteration 1301 / 2450) loss: 1.462739
# (Iteration 1401 / 2450) loss: 1.364534
# (Epoch 6 / 10) train acc: 0.556000; val_acc: 0.532000
# (Iteration 1501 / 2450) loss: 1.397083
# (Iteration 1601 / 2450) loss: 1.360353
# (Iteration 1701 / 2450) loss: 1.340516
# (Epoch 7 / 10) train acc: 0.566000; val_acc: 0.529000
# (Iteration 1801 / 2450) loss: 1.386981
# (Iteration 1901 / 2450) loss: 1.381250
# (Epoch 8 / 10) train acc: 0.556000; val_acc: 0.557000
# (Iteration 2001 / 2450) loss: 1.368260
# (Iteration 2101 / 2450) loss: 1.456779
# (Iteration 2201 / 2450) loss: 1.375952
# (Epoch 9 / 10) train acc: 0.518000; val_acc: 0.552000
# (Iteration 2301 / 2450) loss: 1.416860
# (Iteration 2401 / 2450) loss: 1.331321
# (Epoch 10 / 10) train acc: 0.561000; val_acc: 0.555000
# lr 0.1, reg 0.005, -> val_acc: 0.557
# (Iteration 1 / 2450) loss: 2.302612
# (Epoch 0 / 10) train acc: 0.101000; val_acc: 0.119000
# (Iteration 101 / 2450) loss: 1.372344
# (Iteration 201 / 2450) loss: 1.332703
# (Epoch 1 / 10) train acc: 0.536000; val_acc: 0.518000
# (Iteration 301 / 2450) loss: 1.306366
# (Iteration 401 / 2450) loss: 1.255296
# (Epoch 2 / 10) train acc: 0.553000; val_acc: 0.496000
# (Iteration 501 / 2450) loss: 1.118331
# (Iteration 601 / 2450) loss: 1.378798
# (Iteration 701 / 2450) loss: 1.202311
# (Epoch 3 / 10) train acc: 0.632000; val_acc: 0.585000
# (Iteration 801 / 2450) loss: 1.195852
# (Iteration 901 / 2450) loss: 1.260408
# (Epoch 4 / 10) train acc: 0.609000; val_acc: 0.558000
# (Iteration 1001 / 2450) loss: 1.161364
# (Iteration 1101 / 2450) loss: 1.182025
# (Iteration 1201 / 2450) loss: 1.337069
# (Epoch 5 / 10) train acc: 0.647000; val_acc: 0.550000
# (Iteration 1301 / 2450) loss: 1.054219
# (Iteration 1401 / 2450) loss: 1.010623
# (Epoch 6 / 10) train acc: 0.650000; val_acc: 0.573000
# (Iteration 1501 / 2450) loss: 1.079392
# (Iteration 1601 / 2450) loss: 1.002537
# (Iteration 1701 / 2450) loss: 1.002143
# (Epoch 7 / 10) train acc: 0.659000; val_acc: 0.568000
# (Iteration 1801 / 2450) loss: 1.295908
# (Iteration 1901 / 2450) loss: 0.965728
# (Epoch 8 / 10) train acc: 0.710000; val_acc: 0.564000
# (Iteration 2001 / 2450) loss: 1.200726
# (Iteration 2101 / 2450) loss: 1.086543
# (Iteration 2201 / 2450) loss: 0.960619
# (Epoch 9 / 10) train acc: 0.700000; val_acc: 0.577000
# (Iteration 2301 / 2450) loss: 1.089137
# (Iteration 2401 / 2450) loss: 0.993177
# (Epoch 10 / 10) train acc: 0.744000; val_acc: 0.572000
# lr 1, reg 0.001, -> val_acc: 0.585
# (Iteration 1 / 2450) loss: 2.302649
# (Epoch 0 / 10) train acc: 0.092000; val_acc: 0.112000
# (Iteration 101 / 2450) loss: 1.373656
# (Iteration 201 / 2450) loss: 1.543752
# (Epoch 1 / 10) train acc: 0.549000; val_acc: 0.527000
# (Iteration 301 / 2450) loss: 1.438633
# (Iteration 401 / 2450) loss: 1.404520
# (Epoch 2 / 10) train acc: 0.567000; val_acc: 0.532000
# (Iteration 501 / 2450) loss: 1.343420
# (Iteration 601 / 2450) loss: 1.263519
# (Iteration 701 / 2450) loss: 1.459796
# (Epoch 3 / 10) train acc: 0.621000; val_acc: 0.563000
# (Iteration 801 / 2450) loss: 1.304169
# (Iteration 901 / 2450) loss: 1.263027
# (Epoch 4 / 10) train acc: 0.600000; val_acc: 0.563000
# (Iteration 1001 / 2450) loss: 1.199536
# (Iteration 1101 / 2450) loss: 1.380564
# (Iteration 1201 / 2450) loss: 1.359300
# (Epoch 5 / 10) train acc: 0.611000; val_acc: 0.566000
# (Iteration 1301 / 2450) loss: 1.258045
# (Iteration 1401 / 2450) loss: 1.219619
# (Epoch 6 / 10) train acc: 0.632000; val_acc: 0.558000
# (Iteration 1501 / 2450) loss: 1.175584
# (Iteration 1601 / 2450) loss: 1.300195
# (Iteration 1701 / 2450) loss: 1.194772
# (Epoch 7 / 10) train acc: 0.599000; val_acc: 0.572000
# (Iteration 1801 / 2450) loss: 1.302973
# (Iteration 1901 / 2450) loss: 1.402103
# (Epoch 8 / 10) train acc: 0.640000; val_acc: 0.558000
# (Iteration 2001 / 2450) loss: 1.308108
# (Iteration 2101 / 2450) loss: 1.258414
# (Iteration 2201 / 2450) loss: 1.326148
# (Epoch 9 / 10) train acc: 0.676000; val_acc: 0.585000
# (Iteration 2301 / 2450) loss: 1.213322
# (Iteration 2401 / 2450) loss: 1.388221
# (Epoch 10 / 10) train acc: 0.639000; val_acc: 0.552000
# lr 1, reg 0.003, -> val_acc: 0.585
# (Iteration 1 / 2450) loss: 2.302664
# (Epoch 0 / 10) train acc: 0.105000; val_acc: 0.078000
# (Iteration 101 / 2450) loss: 1.529502
# (Iteration 201 / 2450) loss: 1.601968
# (Epoch 1 / 10) train acc: 0.509000; val_acc: 0.506000
# (Iteration 301 / 2450) loss: 1.516879
# (Iteration 401 / 2450) loss: 1.406255
# (Epoch 2 / 10) train acc: 0.573000; val_acc: 0.503000
# (Iteration 501 / 2450) loss: 1.400083
# (Iteration 601 / 2450) loss: 1.579693
# (Iteration 701 / 2450) loss: 1.394815
# (Epoch 3 / 10) train acc: 0.584000; val_acc: 0.524000
# (Iteration 801 / 2450) loss: 1.448003
# (Iteration 901 / 2450) loss: 1.346058
# (Epoch 4 / 10) train acc: 0.596000; val_acc: 0.555000
# (Iteration 1001 / 2450) loss: 1.520734
# (Iteration 1101 / 2450) loss: 1.432183
# (Iteration 1201 / 2450) loss: 1.381236
# (Epoch 5 / 10) train acc: 0.568000; val_acc: 0.557000
# (Iteration 1301 / 2450) loss: 1.476345
# (Iteration 1401 / 2450) loss: 1.461274
# (Epoch 6 / 10) train acc: 0.606000; val_acc: 0.531000
# (Iteration 1501 / 2450) loss: 1.249277
# (Iteration 1601 / 2450) loss: 1.474804
# (Iteration 1701 / 2450) loss: 1.340769
# (Epoch 7 / 10) train acc: 0.604000; val_acc: 0.582000
# (Iteration 1801 / 2450) loss: 1.309022
# (Iteration 1901 / 2450) loss: 1.468383
# (Epoch 8 / 10) train acc: 0.613000; val_acc: 0.589000
# (Iteration 2001 / 2450) loss: 1.281003
# (Iteration 2101 / 2450) loss: 1.334970
# (Iteration 2201 / 2450) loss: 1.362630
# (Epoch 9 / 10) train acc: 0.605000; val_acc: 0.567000
# (Iteration 2301 / 2450) loss: 1.256406
# (Iteration 2401 / 2450) loss: 1.432029
# (Epoch 10 / 10) train acc: 0.607000; val_acc: 0.542000
# lr 1, reg 0.005, -> val_acc: 0.589
# Best validation accuracy achieved: 0.6

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 58% accuracy. It is also possible to get >60% accuracy
# with careful tuning.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.579

# %%
# Save best model
best_net.save("best_two_layer_net_features.npy")
# Out:
# best_two_layer_net_features.npy saved.

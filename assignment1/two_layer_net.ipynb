# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME

# %% [markdown]
# # Fully-Connected Neural Nets
# In this exercise we will implement fully-connected networks using a modular approach. For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive dout (derivative of loss with respect to outputs) and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.

# %%
# As usual, a bit of setup
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k, v in list(data.items()):
  print(('%s: ' % k, v.shape))
# Out:
# ('X_train: ', (49000, 3, 32, 32))
# ('y_train: ', (49000,))
# ('X_val: ', (1000, 3, 32, 32))
# ('y_val: ', (1000,))
# ('X_test: ', (1000, 3, 32, 32))
# ('y_test: ', (1000,))

# %% [markdown]
# # Affine layer: forward
# Open the file `cs231n/layers.py` and implement the `affine_forward` function.
#
# Once you are done you can test your implementaion by running the following:

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])

# Compare your output with ours. The error should be around e-9 or less.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# difference:  9.769849468192957e-10

# %% [markdown]
# # Affine layer: backward
# Now implement the `affine_backward` function and test your implementation using numeric gradient checking.

# %%
# Test the affine_backward function
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around e-10 or less
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  5.7646647722652796e-11
# dw error:  1.473328934429664e-10
# db error:  7.72167374950876e-11

# %% [markdown]
# # ReLU activation: forward
# Implement the forward pass for the ReLU activation function in the `relu_forward` function and test your implementation using the following:

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# # ReLU activation: backward
# Now implement the backward pass for the ReLU activation function in the `relu_backward` function and test your implementation using numeric gradient checking:

# %%
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be on the order of e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756349136310288e-12

# %% [markdown]
# ## Inline Question 1:
#
# We've only asked you to implement ReLU, but there are a number of different activation functions that one could use in neural networks, each with its pros and cons. In particular, an issue commonly seen with activation functions is getting zero (or close to zero) gradient flow during backpropagation. Which of the following activation functions have this problem? If you consider these functions in the one dimensional case, what types of input would lead to this behaviour?
# 1. Sigmoid
# 2. ReLU
# 3. Leaky ReLU
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*
#
# Sigmoid和ReLU都有梯度消失的问题
#
# Sigmoid:当输入 x 是一个很大的正数时，Sigmoid 的输出 $\delta(x)$ 会非常接近 1。这时，函数的曲线几乎是水平的，所以它的梯度（斜率）接近于 0。
# 当输入 x 是一个很大的负数时，Sigmoid 的输出 $\delta(x)$ 会非常接近 0。同样，曲线也几乎是水平的，梯度也接近于 0。
#
# ReLU:当输入是一个负数的时候，ReLU的输出会是0。

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, affine layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define several convenience layers in the file `cs231n/layer_utils.py`.
#
# For now take a look at the `affine_relu_forward` and `affine_relu_backward` functions, and run the following to numerically gradient check the backward pass:

# %%
from cs231n.layer_utils import affine_relu_forward, affine_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

# Relative error should be around e-10 or less
print('Testing affine_relu_forward and affine_relu_backward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_relu_forward and affine_relu_backward:
# dx error:  6.960477778649495e-11
# dw error:  8.162088973990222e-11
# db error:  7.82672402145899e-12

# %% [markdown]
# # Loss layers: Softmax
# Now implement the loss and gradient for softmax in the `softmax_loss` function in `cs231n/layers.py`. These should be similar to what you implemented in `cs231n/classifiers/softmax.py`. Other loss functions (e.g. `svm_loss`) can also be implemented in a modular way, however, it is not required for this assignment.
#
# You can make sure that the implementations are correct by running the following:

# %%
np.random.seed(231)
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)


dx_num = eval_numerical_gradient(lambda x: softmax_loss(x, y)[0], x, verbose=False)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting softmax_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing softmax_loss:
# loss:  2.3025458445007376
# dx error:  8.234144091578429e-09

# %% [markdown]
# # Two-layer network
# Open the file `cs231n/classifiers/fc_net.py` and complete the implementation of the `TwoLayerNet` class. Read through it to make sure you understand the API. You can run the cell below to test your implementation.

# %%
np.random.seed(231)
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-3
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-7 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.52e-08
# W2 relative error: 3.21e-10
# b1 relative error: 8.37e-09
# b2 relative error: 4.33e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 2.85e-08
# b1 relative error: 1.56e-08
# b2 relative error: 7.76e-10

# %% [markdown]
# # Solver
# Open the file `cs231n/solver.py` and read through it to familiarize yourself with the API. After doing so, use a `Solver` instance to train a `TwoLayerNet` that achieves about `36%` accuracy on the validation set.

# %%
#from assignment1.knn import X_train


input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
model = TwoLayerNet(input_size, hidden_size, num_classes)
solver = None


##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves about 36% #
# accuracy on the validation set.                                            #
##############################################################################
solver = Solver(model =model, data =data,
                    update_rule='sgd',
                    optim_config={
                      'learning_rate': 1e-4,
                    },
                    lr_decay=0.95,
                    num_epochs=5, batch_size=200,
                    print_every=100)
solver.train()

acc = solver.check_accuracy(X =data["X_val"], y=data["y_val"])
print("acc: ", acc)
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# (Iteration 1 / 1225) loss: 2.304617
# (Epoch 0 / 5) train acc: 0.108000; val_acc: 0.135000
# (Iteration 101 / 1225) loss: 2.258401
# (Iteration 201 / 1225) loss: 2.160523
# (Epoch 1 / 5) train acc: 0.209000; val_acc: 0.255000
# (Iteration 301 / 1225) loss: 2.088335
# (Iteration 401 / 1225) loss: 2.034581
# (Epoch 2 / 5) train acc: 0.275000; val_acc: 0.300000
# (Iteration 501 / 1225) loss: 1.920632
# (Iteration 601 / 1225) loss: 1.936100
# (Iteration 701 / 1225) loss: 1.902036
# (Epoch 3 / 5) train acc: 0.335000; val_acc: 0.340000
# (Iteration 801 / 1225) loss: 1.849048
# (Iteration 901 / 1225) loss: 1.857051
# (Epoch 4 / 5) train acc: 0.375000; val_acc: 0.360000
# (Iteration 1001 / 1225) loss: 1.805492
# (Iteration 1101 / 1225) loss: 1.802579
# (Iteration 1201 / 1225) loss: 1.837376
# (Epoch 5 / 5) train acc: 0.355000; val_acc: 0.379000
# acc:  0.379

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.36 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Run this cell to visualize training loss and train / val accuracy

plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(3, 32, 32, -1).transpose(3, 1, 2, 0)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(model)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can (52% could serve as a reference), with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_model = None
best_acc = 0.0


#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_model.                                                          #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on thexs previous exercises.                        #
#################################################################################
learning_rates = [1e-3, 1e-4]
hidden_dims = [50, 100, 200]
epoch_nums = [5, 10, 15]

for learning_rate in learning_rates:
    for hidden_dim in hidden_dims:
        for epoch_num in epoch_nums:
            print(f"----------------------------learning_rate: {learning_rate}, hidden_dim: {hidden_dim}, epoch_num: {epoch_num}------------------------------")
            model = TwoLayerNet(input_size, hidden_dim, num_classes)
            solver = Solver(model =model, data =data,
                    update_rule='sgd',
                    optim_config={
                      'learning_rate': learning_rate,
                    },
                    lr_decay=0.95,
                    num_epochs=epoch_num, batch_size=200,
                    print_every=100)
            solver.train()

            acc = solver.check_accuracy(data["X_val"], data["y_val"])
            if acc > best_acc:
                best_acc = acc
                best_model = model
print("best_acc = ", best_acc)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# ----------------------------learning_rate: 0.001, hidden_dim: 50, epoch_num: 5------------------------------
# (Iteration 1 / 1225) loss: 2.304525
# (Epoch 0 / 5) train acc: 0.134000; val_acc: 0.124000
# (Iteration 101 / 1225) loss: 1.821316
# (Iteration 201 / 1225) loss: 1.670444
# (Epoch 1 / 5) train acc: 0.433000; val_acc: 0.425000
# (Iteration 301 / 1225) loss: 1.626854
# (Iteration 401 / 1225) loss: 1.548406
# (Epoch 2 / 5) train acc: 0.473000; val_acc: 0.463000
# (Iteration 501 / 1225) loss: 1.384435
# (Iteration 601 / 1225) loss: 1.676185
# (Iteration 701 / 1225) loss: 1.477849
# (Epoch 3 / 5) train acc: 0.486000; val_acc: 0.468000
# (Iteration 801 / 1225) loss: 1.445242
# (Iteration 901 / 1225) loss: 1.445058
# (Epoch 4 / 5) train acc: 0.479000; val_acc: 0.488000
# (Iteration 1001 / 1225) loss: 1.538612
# (Iteration 1101 / 1225) loss: 1.352896
# (Iteration 1201 / 1225) loss: 1.476539
# (Epoch 5 / 5) train acc: 0.497000; val_acc: 0.496000
# ----------------------------learning_rate: 0.001, hidden_dim: 50, epoch_num: 10------------------------------
# (Iteration 1 / 2450) loss: 2.301972
# (Epoch 0 / 10) train acc: 0.136000; val_acc: 0.134000
# (Iteration 101 / 2450) loss: 1.840417
# (Iteration 201 / 2450) loss: 1.695213
# (Epoch 1 / 10) train acc: 0.429000; val_acc: 0.431000
# (Iteration 301 / 2450) loss: 1.695058
# (Iteration 401 / 2450) loss: 1.653808
# (Epoch 2 / 10) train acc: 0.475000; val_acc: 0.451000
# (Iteration 501 / 2450) loss: 1.535461
# (Iteration 601 / 2450) loss: 1.466198
# (Iteration 701 / 2450) loss: 1.498581
# (Epoch 3 / 10) train acc: 0.480000; val_acc: 0.468000
# (Iteration 801 / 2450) loss: 1.469103
# (Iteration 901 / 2450) loss: 1.471780
# (Epoch 4 / 10) train acc: 0.495000; val_acc: 0.490000
# (Iteration 1001 / 2450) loss: 1.327981
# (Iteration 1101 / 2450) loss: 1.405922
# (Iteration 1201 / 2450) loss: 1.292564
# (Epoch 5 / 10) train acc: 0.530000; val_acc: 0.494000
# (Iteration 1301 / 2450) loss: 1.346698
# (Iteration 1401 / 2450) loss: 1.298179
# (Epoch 6 / 10) train acc: 0.536000; val_acc: 0.490000
# (Iteration 1501 / 2450) loss: 1.252781
# (Iteration 1601 / 2450) loss: 1.386767
# (Iteration 1701 / 2450) loss: 1.339552
# (Epoch 7 / 10) train acc: 0.549000; val_acc: 0.490000
# (Iteration 1801 / 2450) loss: 1.326223
# (Iteration 1901 / 2450) loss: 1.389130
# (Epoch 8 / 10) train acc: 0.534000; val_acc: 0.507000
# (Iteration 2001 / 2450) loss: 1.328582
# (Iteration 2101 / 2450) loss: 1.375443
# (Iteration 2201 / 2450) loss: 1.312543
# (Epoch 9 / 10) train acc: 0.554000; val_acc: 0.502000
# (Iteration 2301 / 2450) loss: 1.331374
# (Iteration 2401 / 2450) loss: 1.362028
# (Epoch 10 / 10) train acc: 0.572000; val_acc: 0.525000
# ----------------------------learning_rate: 0.001, hidden_dim: 50, epoch_num: 15------------------------------
# (Iteration 1 / 3675) loss: 2.304193
# (Epoch 0 / 15) train acc: 0.106000; val_acc: 0.097000
# (Iteration 101 / 3675) loss: 1.921625
# (Iteration 201 / 3675) loss: 1.615405
# (Epoch 1 / 15) train acc: 0.412000; val_acc: 0.431000
# (Iteration 301 / 3675) loss: 1.739250
# (Iteration 401 / 3675) loss: 1.548461
# (Epoch 2 / 15) train acc: 0.462000; val_acc: 0.458000
# (Iteration 501 / 3675) loss: 1.429437
# (Iteration 601 / 3675) loss: 1.357646
# (Iteration 701 / 3675) loss: 1.501822
# (Epoch 3 / 15) train acc: 0.478000; val_acc: 0.456000
# (Iteration 801 / 3675) loss: 1.402082
# (Iteration 901 / 3675) loss: 1.497397
# (Epoch 4 / 15) train acc: 0.493000; val_acc: 0.453000
# (Iteration 1001 / 3675) loss: 1.455442
# (Iteration 1101 / 3675) loss: 1.442160
# (Iteration 1201 / 3675) loss: 1.497829
# (Epoch 5 / 15) train acc: 0.511000; val_acc: 0.478000
# (Iteration 1301 / 3675) loss: 1.321652
# (Iteration 1401 / 3675) loss: 1.425674
# (Epoch 6 / 15) train acc: 0.522000; val_acc: 0.502000
# (Iteration 1501 / 3675) loss: 1.492140
# (Iteration 1601 / 3675) loss: 1.427697
# (Iteration 1701 / 3675) loss: 1.388341
# (Epoch 7 / 15) train acc: 0.532000; val_acc: 0.499000
# (Iteration 1801 / 3675) loss: 1.249034
# (Iteration 1901 / 3675) loss: 1.257210
# (Epoch 8 / 15) train acc: 0.556000; val_acc: 0.491000
# (Iteration 2001 / 3675) loss: 1.159726
# (Iteration 2101 / 3675) loss: 1.238070
# (Iteration 2201 / 3675) loss: 1.308311
# (Epoch 9 / 15) train acc: 0.561000; val_acc: 0.496000
# (Iteration 2301 / 3675) loss: 1.203566
# (Iteration 2401 / 3675) loss: 1.352709
# (Epoch 10 / 15) train acc: 0.555000; val_acc: 0.507000
# (Iteration 2501 / 3675) loss: 1.303470
# (Iteration 2601 / 3675) loss: 1.235664
# (Epoch 11 / 15) train acc: 0.579000; val_acc: 0.496000
# (Iteration 2701 / 3675) loss: 1.116716
# (Iteration 2801 / 3675) loss: 1.239283
# (Iteration 2901 / 3675) loss: 1.247697
# (Epoch 12 / 15) train acc: 0.574000; val_acc: 0.509000
# (Iteration 3001 / 3675) loss: 1.234461
# (Iteration 3101 / 3675) loss: 1.212876
# (Epoch 13 / 15) train acc: 0.565000; val_acc: 0.501000
# (Iteration 3201 / 3675) loss: 1.167370
# (Iteration 3301 / 3675) loss: 1.327598
# (Iteration 3401 / 3675) loss: 1.282505
# (Epoch 14 / 15) train acc: 0.578000; val_acc: 0.520000
# (Iteration 3501 / 3675) loss: 1.224256
# (Iteration 3601 / 3675) loss: 1.146740
# (Epoch 15 / 15) train acc: 0.592000; val_acc: 0.528000
# ----------------------------learning_rate: 0.001, hidden_dim: 100, epoch_num: 5------------------------------
# (Iteration 1 / 1225) loss: 2.306954
# (Epoch 0 / 5) train acc: 0.110000; val_acc: 0.118000
# (Iteration 101 / 1225) loss: 1.818267
# (Iteration 201 / 1225) loss: 1.633465
# (Epoch 1 / 5) train acc: 0.447000; val_acc: 0.442000
# (Iteration 301 / 1225) loss: 1.745597
# (Iteration 401 / 1225) loss: 1.624530
# (Epoch 2 / 5) train acc: 0.484000; val_acc: 0.436000
# (Iteration 501 / 1225) loss: 1.489806
# (Iteration 601 / 1225) loss: 1.435007
# (Iteration 701 / 1225) loss: 1.388541
# (Epoch 3 / 5) train acc: 0.507000; val_acc: 0.479000
# (Iteration 801 / 1225) loss: 1.358711
# (Iteration 901 / 1225) loss: 1.382255
# (Epoch 4 / 5) train acc: 0.479000; val_acc: 0.484000
# (Iteration 1001 / 1225) loss: 1.348461
# (Iteration 1101 / 1225) loss: 1.360390
# (Iteration 1201 / 1225) loss: 1.392438
# (Epoch 5 / 5) train acc: 0.530000; val_acc: 0.489000
# ----------------------------learning_rate: 0.001, hidden_dim: 100, epoch_num: 10------------------------------
# (Iteration 1 / 2450) loss: 2.296418
# (Epoch 0 / 10) train acc: 0.162000; val_acc: 0.143000
# (Iteration 101 / 2450) loss: 1.821266
# (Iteration 201 / 2450) loss: 1.654635
# (Epoch 1 / 10) train acc: 0.430000; val_acc: 0.433000
# (Iteration 301 / 2450) loss: 1.539462
# (Iteration 401 / 2450) loss: 1.444694
# (Epoch 2 / 10) train acc: 0.469000; val_acc: 0.440000
# (Iteration 501 / 2450) loss: 1.500808
# (Iteration 601 / 2450) loss: 1.597693
# (Iteration 701 / 2450) loss: 1.404371
# (Epoch 3 / 10) train acc: 0.520000; val_acc: 0.495000
# (Iteration 801 / 2450) loss: 1.316303
# (Iteration 901 / 2450) loss: 1.445390
# (Epoch 4 / 10) train acc: 0.517000; val_acc: 0.497000
# (Iteration 1001 / 2450) loss: 1.432118
# (Iteration 1101 / 2450) loss: 1.298115
# (Iteration 1201 / 2450) loss: 1.334116
# (Epoch 5 / 10) train acc: 0.514000; val_acc: 0.499000
# (Iteration 1301 / 2450) loss: 1.299315
# (Iteration 1401 / 2450) loss: 1.380285
# (Epoch 6 / 10) train acc: 0.556000; val_acc: 0.494000
# (Iteration 1501 / 2450) loss: 1.222375
# (Iteration 1601 / 2450) loss: 1.389772
# (Iteration 1701 / 2450) loss: 1.132730
# (Epoch 7 / 10) train acc: 0.546000; val_acc: 0.501000
# (Iteration 1801 / 2450) loss: 1.274535
# (Iteration 1901 / 2450) loss: 1.271438
# (Epoch 8 / 10) train acc: 0.582000; val_acc: 0.506000
# (Iteration 2001 / 2450) loss: 1.285876
# (Iteration 2101 / 2450) loss: 1.256792
# (Iteration 2201 / 2450) loss: 1.085006
# (Epoch 9 / 10) train acc: 0.558000; val_acc: 0.487000
# (Iteration 2301 / 2450) loss: 1.251819
# (Iteration 2401 / 2450) loss: 1.104831
# (Epoch 10 / 10) train acc: 0.564000; val_acc: 0.504000
# ----------------------------learning_rate: 0.001, hidden_dim: 100, epoch_num: 15------------------------------
# (Iteration 1 / 3675) loss: 2.303091
# (Epoch 0 / 15) train acc: 0.159000; val_acc: 0.124000
# (Iteration 101 / 3675) loss: 1.850869
# (Iteration 201 / 3675) loss: 1.650057
# (Epoch 1 / 15) train acc: 0.418000; val_acc: 0.423000
# (Iteration 301 / 3675) loss: 1.506340
# (Iteration 401 / 3675) loss: 1.567528
# (Epoch 2 / 15) train acc: 0.468000; val_acc: 0.463000
# (Iteration 501 / 3675) loss: 1.446039
# (Iteration 601 / 3675) loss: 1.487854
# (Iteration 701 / 3675) loss: 1.414125
# (Epoch 3 / 15) train acc: 0.499000; val_acc: 0.501000
# (Iteration 801 / 3675) loss: 1.441224
# (Iteration 901 / 3675) loss: 1.474427
# (Epoch 4 / 15) train acc: 0.531000; val_acc: 0.488000
# (Iteration 1001 / 3675) loss: 1.379587
# (Iteration 1101 / 3675) loss: 1.414976
# (Iteration 1201 / 3675) loss: 1.272623
# (Epoch 5 / 15) train acc: 0.511000; val_acc: 0.515000
# (Iteration 1301 / 3675) loss: 1.312715
# (Iteration 1401 / 3675) loss: 1.315006
# (Epoch 6 / 15) train acc: 0.548000; val_acc: 0.516000
# (Iteration 1501 / 3675) loss: 1.416327
# (Iteration 1601 / 3675) loss: 1.272741
# (Iteration 1701 / 3675) loss: 1.292235
# (Epoch 7 / 15) train acc: 0.574000; val_acc: 0.515000
# (Iteration 1801 / 3675) loss: 1.180238
# (Iteration 1901 / 3675) loss: 1.298048
# (Epoch 8 / 15) train acc: 0.583000; val_acc: 0.501000
# (Iteration 2001 / 3675) loss: 1.156331
# (Iteration 2101 / 3675) loss: 1.204656
# (Iteration 2201 / 3675) loss: 1.201014
# (Epoch 9 / 15) train acc: 0.570000; val_acc: 0.504000
# (Iteration 2301 / 3675) loss: 1.184326
# (Iteration 2401 / 3675) loss: 0.977774
# (Epoch 10 / 15) train acc: 0.592000; val_acc: 0.521000
# (Iteration 2501 / 3675) loss: 1.221526
# (Iteration 2601 / 3675) loss: 1.140066
# (Epoch 11 / 15) train acc: 0.583000; val_acc: 0.518000
# (Iteration 2701 / 3675) loss: 1.044155
# (Iteration 2801 / 3675) loss: 0.956942
# (Iteration 2901 / 3675) loss: 1.109567
# (Epoch 12 / 15) train acc: 0.633000; val_acc: 0.517000
# (Iteration 3001 / 3675) loss: 1.030500
# (Iteration 3101 / 3675) loss: 1.059763
# (Epoch 13 / 15) train acc: 0.621000; val_acc: 0.517000
# (Iteration 3201 / 3675) loss: 1.063374
# (Iteration 3301 / 3675) loss: 0.982250
# (Iteration 3401 / 3675) loss: 1.265476
# (Epoch 14 / 15) train acc: 0.637000; val_acc: 0.533000
# (Iteration 3501 / 3675) loss: 0.992245
# (Iteration 3601 / 3675) loss: 1.185235
# (Epoch 15 / 15) train acc: 0.624000; val_acc: 0.523000
# ----------------------------learning_rate: 0.001, hidden_dim: 200, epoch_num: 5------------------------------
# (Iteration 1 / 1225) loss: 2.305465
# (Epoch 0 / 5) train acc: 0.137000; val_acc: 0.148000
# (Iteration 101 / 1225) loss: 1.735741
# (Iteration 201 / 1225) loss: 1.541521
# (Epoch 1 / 5) train acc: 0.422000; val_acc: 0.450000
# (Iteration 301 / 1225) loss: 1.457830
# (Iteration 401 / 1225) loss: 1.527660
# (Epoch 2 / 5) train acc: 0.475000; val_acc: 0.475000
# (Iteration 501 / 1225) loss: 1.565894
# (Iteration 601 / 1225) loss: 1.366292
# (Iteration 701 / 1225) loss: 1.342941
# (Epoch 3 / 5) train acc: 0.494000; val_acc: 0.492000
# (Iteration 801 / 1225) loss: 1.404231
# (Iteration 901 / 1225) loss: 1.334613
# (Epoch 4 / 5) train acc: 0.534000; val_acc: 0.489000
# (Iteration 1001 / 1225) loss: 1.412044
# (Iteration 1101 / 1225) loss: 1.365895
# (Iteration 1201 / 1225) loss: 1.366510
# (Epoch 5 / 5) train acc: 0.558000; val_acc: 0.513000
# ----------------------------learning_rate: 0.001, hidden_dim: 200, epoch_num: 10------------------------------
# (Iteration 1 / 2450) loss: 2.302194
# (Epoch 0 / 10) train acc: 0.149000; val_acc: 0.132000
# (Iteration 101 / 2450) loss: 1.761036
# (Iteration 201 / 2450) loss: 1.579195
# (Epoch 1 / 10) train acc: 0.423000; val_acc: 0.451000
# (Iteration 301 / 2450) loss: 1.532924
# (Iteration 401 / 2450) loss: 1.564609
# (Epoch 2 / 10) train acc: 0.500000; val_acc: 0.471000
# (Iteration 501 / 2450) loss: 1.492063
# (Iteration 601 / 2450) loss: 1.373678
# (Iteration 701 / 2450) loss: 1.428103
# (Epoch 3 / 10) train acc: 0.512000; val_acc: 0.483000
# (Iteration 801 / 2450) loss: 1.483110
# (Iteration 901 / 2450) loss: 1.452222
# (Epoch 4 / 10) train acc: 0.529000; val_acc: 0.499000
# (Iteration 1001 / 2450) loss: 1.470538
# (Iteration 1101 / 2450) loss: 1.309480
# (Iteration 1201 / 2450) loss: 1.171392
# (Epoch 5 / 10) train acc: 0.590000; val_acc: 0.511000
# (Iteration 1301 / 2450) loss: 1.324268
# (Iteration 1401 / 2450) loss: 1.312854
# (Epoch 6 / 10) train acc: 0.562000; val_acc: 0.516000
# (Iteration 1501 / 2450) loss: 1.188540
# (Iteration 1601 / 2450) loss: 1.150440
# (Iteration 1701 / 2450) loss: 1.182387
# (Epoch 7 / 10) train acc: 0.577000; val_acc: 0.528000
# (Iteration 1801 / 2450) loss: 1.154165
# (Iteration 1901 / 2450) loss: 1.356798
# (Epoch 8 / 10) train acc: 0.591000; val_acc: 0.519000
# (Iteration 2001 / 2450) loss: 1.118655
# (Iteration 2101 / 2450) loss: 0.998105
# (Iteration 2201 / 2450) loss: 1.147722
# (Epoch 9 / 10) train acc: 0.604000; val_acc: 0.513000
# (Iteration 2301 / 2450) loss: 1.233454
# (Iteration 2401 / 2450) loss: 1.032856
# (Epoch 10 / 10) train acc: 0.620000; val_acc: 0.519000
# ----------------------------learning_rate: 0.001, hidden_dim: 200, epoch_num: 15------------------------------
# (Iteration 1 / 3675) loss: 2.303150
# (Epoch 0 / 15) train acc: 0.144000; val_acc: 0.152000
# (Iteration 101 / 3675) loss: 1.776285
# (Iteration 201 / 3675) loss: 1.556470
# (Epoch 1 / 15) train acc: 0.431000; val_acc: 0.424000
# (Iteration 301 / 3675) loss: 1.725640
# (Iteration 401 / 3675) loss: 1.517127
# (Epoch 2 / 15) train acc: 0.455000; val_acc: 0.444000
# (Iteration 501 / 3675) loss: 1.593682
# (Iteration 601 / 3675) loss: 1.408118
# (Iteration 701 / 3675) loss: 1.481842
# (Epoch 3 / 15) train acc: 0.485000; val_acc: 0.474000
# (Iteration 801 / 3675) loss: 1.293873
# (Iteration 901 / 3675) loss: 1.248552
# (Epoch 4 / 15) train acc: 0.541000; val_acc: 0.496000
# (Iteration 1001 / 3675) loss: 1.360249
# (Iteration 1101 / 3675) loss: 1.251144
# (Iteration 1201 / 3675) loss: 1.263455
# (Epoch 5 / 15) train acc: 0.561000; val_acc: 0.504000
# (Iteration 1301 / 3675) loss: 1.158680
# (Iteration 1401 / 3675) loss: 1.463880
# (Epoch 6 / 15) train acc: 0.559000; val_acc: 0.493000
# (Iteration 1501 / 3675) loss: 1.262338
# (Iteration 1601 / 3675) loss: 1.112493
# (Iteration 1701 / 3675) loss: 1.332132
# (Epoch 7 / 15) train acc: 0.597000; val_acc: 0.521000
# (Iteration 1801 / 3675) loss: 1.157216
# (Iteration 1901 / 3675) loss: 1.093844
# (Epoch 8 / 15) train acc: 0.577000; val_acc: 0.523000
# (Iteration 2001 / 3675) loss: 1.122272
# (Iteration 2101 / 3675) loss: 1.173370
# (Iteration 2201 / 3675) loss: 1.128046
# (Epoch 9 / 15) train acc: 0.632000; val_acc: 0.517000
# (Iteration 2301 / 3675) loss: 1.147115
# (Iteration 2401 / 3675) loss: 1.103629
# (Epoch 10 / 15) train acc: 0.632000; val_acc: 0.521000
# (Iteration 2501 / 3675) loss: 1.125164
# (Iteration 2601 / 3675) loss: 1.144261
# (Epoch 11 / 15) train acc: 0.632000; val_acc: 0.527000
# (Iteration 2701 / 3675) loss: 1.136676
# (Iteration 2801 / 3675) loss: 0.972278
# (Iteration 2901 / 3675) loss: 1.074768
# (Epoch 12 / 15) train acc: 0.668000; val_acc: 0.531000
# (Iteration 3001 / 3675) loss: 1.002604
# (Iteration 3101 / 3675) loss: 0.879781
# (Epoch 13 / 15) train acc: 0.634000; val_acc: 0.533000
# (Iteration 3201 / 3675) loss: 1.063362
# (Iteration 3301 / 3675) loss: 0.869139
# (Iteration 3401 / 3675) loss: 1.038714
# (Epoch 14 / 15) train acc: 0.678000; val_acc: 0.547000
# (Iteration 3501 / 3675) loss: 1.090763
# (Iteration 3601 / 3675) loss: 1.083702
# (Epoch 15 / 15) train acc: 0.659000; val_acc: 0.542000
# ----------------------------learning_rate: 0.0001, hidden_dim: 50, epoch_num: 5------------------------------
# (Iteration 1 / 1225) loss: 2.305246
# (Epoch 0 / 5) train acc: 0.068000; val_acc: 0.062000
# (Iteration 101 / 1225) loss: 2.264788
# (Iteration 201 / 1225) loss: 2.204793
# (Epoch 1 / 5) train acc: 0.228000; val_acc: 0.236000
# (Iteration 301 / 1225) loss: 2.054803
# (Iteration 401 / 1225) loss: 2.077313
# (Epoch 2 / 5) train acc: 0.298000; val_acc: 0.291000
# (Iteration 501 / 1225) loss: 2.052719
# (Iteration 601 / 1225) loss: 1.853439
# (Iteration 701 / 1225) loss: 1.842327
# (Epoch 3 / 5) train acc: 0.307000; val_acc: 0.326000
# (Iteration 801 / 1225) loss: 1.845003
# (Iteration 901 / 1225) loss: 1.789813
# (Epoch 4 / 5) train acc: 0.372000; val_acc: 0.355000
# (Iteration 1001 / 1225) loss: 1.827304
# (Iteration 1101 / 1225) loss: 1.870639
# (Iteration 1201 / 1225) loss: 1.826965
# (Epoch 5 / 5) train acc: 0.361000; val_acc: 0.371000
# ----------------------------learning_rate: 0.0001, hidden_dim: 50, epoch_num: 10------------------------------
# (Iteration 1 / 2450) loss: 2.299334
# (Epoch 0 / 10) train acc: 0.150000; val_acc: 0.116000
# (Iteration 101 / 2450) loss: 2.262776
# (Iteration 201 / 2450) loss: 2.160612
# (Epoch 1 / 10) train acc: 0.229000; val_acc: 0.250000
# (Iteration 301 / 2450) loss: 2.028888
# (Iteration 401 / 2450) loss: 2.062631
# (Epoch 2 / 10) train acc: 0.273000; val_acc: 0.296000
# (Iteration 501 / 2450) loss: 1.958873
# (Iteration 601 / 2450) loss: 1.834582
# (Iteration 701 / 2450) loss: 1.876593
# (Epoch 3 / 10) train acc: 0.334000; val_acc: 0.328000
# (Iteration 801 / 2450) loss: 1.952514
# (Iteration 901 / 2450) loss: 1.796176
# (Epoch 4 / 10) train acc: 0.363000; val_acc: 0.356000
# (Iteration 1001 / 2450) loss: 1.843105
# (Iteration 1101 / 2450) loss: 1.761519
# (Iteration 1201 / 2450) loss: 1.714609
# (Epoch 5 / 10) train acc: 0.396000; val_acc: 0.377000
# (Iteration 1301 / 2450) loss: 1.803869
# (Iteration 1401 / 2450) loss: 1.698369
# (Epoch 6 / 10) train acc: 0.386000; val_acc: 0.394000
# (Iteration 1501 / 2450) loss: 1.651193
# (Iteration 1601 / 2450) loss: 1.662158
# (Iteration 1701 / 2450) loss: 1.720885
# (Epoch 7 / 10) train acc: 0.413000; val_acc: 0.397000
# (Iteration 1801 / 2450) loss: 1.804028
# (Iteration 1901 / 2450) loss: 1.660536
# (Epoch 8 / 10) train acc: 0.405000; val_acc: 0.401000
# (Iteration 2001 / 2450) loss: 1.587854
# (Iteration 2101 / 2450) loss: 1.664363
# (Iteration 2201 / 2450) loss: 1.538948
# (Epoch 9 / 10) train acc: 0.396000; val_acc: 0.420000
# (Iteration 2301 / 2450) loss: 1.647062
# (Iteration 2401 / 2450) loss: 1.717435
# (Epoch 10 / 10) train acc: 0.430000; val_acc: 0.436000
# ----------------------------learning_rate: 0.0001, hidden_dim: 50, epoch_num: 15------------------------------
# (Iteration 1 / 3675) loss: 2.305029
# (Epoch 0 / 15) train acc: 0.108000; val_acc: 0.126000
# (Iteration 101 / 3675) loss: 2.258606
# (Iteration 201 / 3675) loss: 2.145845
# (Epoch 1 / 15) train acc: 0.225000; val_acc: 0.255000
# (Iteration 301 / 3675) loss: 2.059199
# (Iteration 401 / 3675) loss: 1.924146
# (Epoch 2 / 15) train acc: 0.289000; val_acc: 0.292000
# (Iteration 501 / 3675) loss: 1.941679
# (Iteration 601 / 3675) loss: 1.935324
# (Iteration 701 / 3675) loss: 1.955311
# (Epoch 3 / 15) train acc: 0.329000; val_acc: 0.337000
# (Iteration 801 / 3675) loss: 1.857388
# (Iteration 901 / 3675) loss: 1.742636
# (Epoch 4 / 15) train acc: 0.362000; val_acc: 0.358000
# (Iteration 1001 / 3675) loss: 1.846265
# (Iteration 1101 / 3675) loss: 1.871372
# (Iteration 1201 / 3675) loss: 1.834203
# (Epoch 5 / 15) train acc: 0.401000; val_acc: 0.373000
# (Iteration 1301 / 3675) loss: 1.769688
# (Iteration 1401 / 3675) loss: 1.729415
# (Epoch 6 / 15) train acc: 0.378000; val_acc: 0.398000
# (Iteration 1501 / 3675) loss: 1.775523
# (Iteration 1601 / 3675) loss: 1.748752
# (Iteration 1701 / 3675) loss: 1.720110
# (Epoch 7 / 15) train acc: 0.393000; val_acc: 0.401000
# (Iteration 1801 / 3675) loss: 1.675972
# (Iteration 1901 / 3675) loss: 1.599336
# (Epoch 8 / 15) train acc: 0.363000; val_acc: 0.423000
# (Iteration 2001 / 3675) loss: 1.688349
# (Iteration 2101 / 3675) loss: 1.642936
# (Iteration 2201 / 3675) loss: 1.687927
# (Epoch 9 / 15) train acc: 0.419000; val_acc: 0.426000
# (Iteration 2301 / 3675) loss: 1.660853
# (Iteration 2401 / 3675) loss: 1.729646
# (Epoch 10 / 15) train acc: 0.405000; val_acc: 0.432000
# (Iteration 2501 / 3675) loss: 1.500872
# (Iteration 2601 / 3675) loss: 1.727633
# (Epoch 11 / 15) train acc: 0.443000; val_acc: 0.439000
# (Iteration 2701 / 3675) loss: 1.707284
# (Iteration 2801 / 3675) loss: 1.445769
# (Iteration 2901 / 3675) loss: 1.586404
# (Epoch 12 / 15) train acc: 0.412000; val_acc: 0.442000
# (Iteration 3001 / 3675) loss: 1.650681
# (Iteration 3101 / 3675) loss: 1.673764
# (Epoch 13 / 15) train acc: 0.425000; val_acc: 0.442000
# (Iteration 3201 / 3675) loss: 1.574212
# (Iteration 3301 / 3675) loss: 1.721323
# (Iteration 3401 / 3675) loss: 1.679876
# (Epoch 14 / 15) train acc: 0.448000; val_acc: 0.440000
# (Iteration 3501 / 3675) loss: 1.703285
# (Iteration 3601 / 3675) loss: 1.618802
# (Epoch 15 / 15) train acc: 0.416000; val_acc: 0.455000
# ----------------------------learning_rate: 0.0001, hidden_dim: 100, epoch_num: 5------------------------------
# (Iteration 1 / 1225) loss: 2.305426
# (Epoch 0 / 5) train acc: 0.103000; val_acc: 0.111000
# (Iteration 101 / 1225) loss: 2.224460
# (Iteration 201 / 1225) loss: 2.192036
# (Epoch 1 / 5) train acc: 0.251000; val_acc: 0.271000
# (Iteration 301 / 1225) loss: 2.029838
# (Iteration 401 / 1225) loss: 1.993903
# (Epoch 2 / 5) train acc: 0.283000; val_acc: 0.297000
# (Iteration 501 / 1225) loss: 2.036929
# (Iteration 601 / 1225) loss: 1.810228
# (Iteration 701 / 1225) loss: 1.977802
# (Epoch 3 / 5) train acc: 0.304000; val_acc: 0.334000
# (Iteration 801 / 1225) loss: 1.845627
# (Iteration 901 / 1225) loss: 1.796470
# (Epoch 4 / 5) train acc: 0.372000; val_acc: 0.370000
# (Iteration 1001 / 1225) loss: 1.733031
# (Iteration 1101 / 1225) loss: 1.855166
# (Iteration 1201 / 1225) loss: 1.756846
# (Epoch 5 / 5) train acc: 0.403000; val_acc: 0.389000
# ----------------------------learning_rate: 0.0001, hidden_dim: 100, epoch_num: 10------------------------------
# (Iteration 1 / 2450) loss: 2.305218
# (Epoch 0 / 10) train acc: 0.068000; val_acc: 0.095000
# (Iteration 101 / 2450) loss: 2.221979
# (Iteration 201 / 2450) loss: 2.154789
# (Epoch 1 / 10) train acc: 0.252000; val_acc: 0.277000
# (Iteration 301 / 2450) loss: 2.016882
# (Iteration 401 / 2450) loss: 1.977082
# (Epoch 2 / 10) train acc: 0.316000; val_acc: 0.315000
# (Iteration 501 / 2450) loss: 2.006919
# (Iteration 601 / 2450) loss: 1.851756
# (Iteration 701 / 2450) loss: 1.856285
# (Epoch 3 / 10) train acc: 0.335000; val_acc: 0.339000
# (Iteration 801 / 2450) loss: 1.872725
# (Iteration 901 / 2450) loss: 1.804642
# (Epoch 4 / 10) train acc: 0.381000; val_acc: 0.369000
# (Iteration 1001 / 2450) loss: 1.701901
# (Iteration 1101 / 2450) loss: 1.735961
# (Iteration 1201 / 2450) loss: 1.790757
# (Epoch 5 / 10) train acc: 0.396000; val_acc: 0.380000
# (Iteration 1301 / 2450) loss: 1.700328
# (Iteration 1401 / 2450) loss: 1.733669
# (Epoch 6 / 10) train acc: 0.383000; val_acc: 0.393000
# (Iteration 1501 / 2450) loss: 1.670674
# (Iteration 1601 / 2450) loss: 1.691795
# (Iteration 1701 / 2450) loss: 1.690169
# (Epoch 7 / 10) train acc: 0.401000; val_acc: 0.398000
# (Iteration 1801 / 2450) loss: 1.584297
# (Iteration 1901 / 2450) loss: 1.619530
# (Epoch 8 / 10) train acc: 0.422000; val_acc: 0.409000
# (Iteration 2001 / 2450) loss: 1.666550
# (Iteration 2101 / 2450) loss: 1.730572
# (Iteration 2201 / 2450) loss: 1.651327
# (Epoch 9 / 10) train acc: 0.395000; val_acc: 0.433000
# (Iteration 2301 / 2450) loss: 1.592305
# (Iteration 2401 / 2450) loss: 1.575250
# (Epoch 10 / 10) train acc: 0.415000; val_acc: 0.440000
# ----------------------------learning_rate: 0.0001, hidden_dim: 100, epoch_num: 15------------------------------
# (Iteration 1 / 3675) loss: 2.302745
# (Epoch 0 / 15) train acc: 0.112000; val_acc: 0.119000
# (Iteration 101 / 3675) loss: 2.247736
# (Iteration 201 / 3675) loss: 2.114091
# (Epoch 1 / 15) train acc: 0.270000; val_acc: 0.274000
# (Iteration 301 / 3675) loss: 2.045056
# (Iteration 401 / 3675) loss: 1.968734
# (Epoch 2 / 15) train acc: 0.287000; val_acc: 0.305000
# (Iteration 501 / 3675) loss: 1.918877
# (Iteration 601 / 3675) loss: 1.885804
# (Iteration 701 / 3675) loss: 1.901636
# (Epoch 3 / 15) train acc: 0.328000; val_acc: 0.340000
# (Iteration 801 / 3675) loss: 1.849389
# (Iteration 901 / 3675) loss: 1.785141
# (Epoch 4 / 15) train acc: 0.332000; val_acc: 0.368000
# (Iteration 1001 / 3675) loss: 1.829745
# (Iteration 1101 / 3675) loss: 1.737225
# (Iteration 1201 / 3675) loss: 1.616856
# (Epoch 5 / 15) train acc: 0.394000; val_acc: 0.375000
# (Iteration 1301 / 3675) loss: 1.733763
# (Iteration 1401 / 3675) loss: 1.805820
# (Epoch 6 / 15) train acc: 0.414000; val_acc: 0.397000
# (Iteration 1501 / 3675) loss: 1.726168
# (Iteration 1601 / 3675) loss: 1.719750
# (Iteration 1701 / 3675) loss: 1.759108
# (Epoch 7 / 15) train acc: 0.390000; val_acc: 0.406000
# (Iteration 1801 / 3675) loss: 1.685032
# (Iteration 1901 / 3675) loss: 1.641448
# (Epoch 8 / 15) train acc: 0.416000; val_acc: 0.405000
# (Iteration 2001 / 3675) loss: 1.609995
# (Iteration 2101 / 3675) loss: 1.725012
# (Iteration 2201 / 3675) loss: 1.675152
# (Epoch 9 / 15) train acc: 0.423000; val_acc: 0.415000
# (Iteration 2301 / 3675) loss: 1.817313
# (Iteration 2401 / 3675) loss: 1.662740
# (Epoch 10 / 15) train acc: 0.435000; val_acc: 0.425000
# (Iteration 2501 / 3675) loss: 1.670397
# (Iteration 2601 / 3675) loss: 1.659759
# (Epoch 11 / 15) train acc: 0.446000; val_acc: 0.435000
# (Iteration 2701 / 3675) loss: 1.592354
# (Iteration 2801 / 3675) loss: 1.517445
# (Iteration 2901 / 3675) loss: 1.431680
# (Epoch 12 / 15) train acc: 0.427000; val_acc: 0.437000
# (Iteration 3001 / 3675) loss: 1.638783
# (Iteration 3101 / 3675) loss: 1.625874
# (Epoch 13 / 15) train acc: 0.439000; val_acc: 0.440000
# (Iteration 3201 / 3675) loss: 1.625810
# (Iteration 3301 / 3675) loss: 1.654920
# (Iteration 3401 / 3675) loss: 1.660778
# (Epoch 14 / 15) train acc: 0.430000; val_acc: 0.447000
# (Iteration 3501 / 3675) loss: 1.589507
# (Iteration 3601 / 3675) loss: 1.503949
# (Epoch 15 / 15) train acc: 0.431000; val_acc: 0.452000
# ----------------------------learning_rate: 0.0001, hidden_dim: 200, epoch_num: 5------------------------------
# (Iteration 1 / 1225) loss: 2.306733
# (Epoch 0 / 5) train acc: 0.082000; val_acc: 0.078000
# (Iteration 101 / 1225) loss: 2.179127
# (Iteration 201 / 1225) loss: 2.069281
# (Epoch 1 / 5) train acc: 0.282000; val_acc: 0.301000
# (Iteration 301 / 1225) loss: 2.082360
# (Iteration 401 / 1225) loss: 1.898585
# (Epoch 2 / 5) train acc: 0.339000; val_acc: 0.330000
# (Iteration 501 / 1225) loss: 1.882983
# (Iteration 601 / 1225) loss: 1.841899
# (Iteration 701 / 1225) loss: 1.879605
# (Epoch 3 / 5) train acc: 0.353000; val_acc: 0.362000
# (Iteration 801 / 1225) loss: 1.692363
# (Iteration 901 / 1225) loss: 1.685240
# (Epoch 4 / 5) train acc: 0.370000; val_acc: 0.384000
# (Iteration 1001 / 1225) loss: 1.817150
# (Iteration 1101 / 1225) loss: 1.763490
# (Iteration 1201 / 1225) loss: 1.602103
# (Epoch 5 / 5) train acc: 0.421000; val_acc: 0.393000
# ----------------------------learning_rate: 0.0001, hidden_dim: 200, epoch_num: 10------------------------------
# (Iteration 1 / 2450) loss: 2.304637
# (Epoch 0 / 10) train acc: 0.132000; val_acc: 0.102000
# (Iteration 101 / 2450) loss: 2.193975
# (Iteration 201 / 2450) loss: 2.039108
# (Epoch 1 / 10) train acc: 0.297000; val_acc: 0.295000
# (Iteration 301 / 2450) loss: 1.982693
# (Iteration 401 / 2450) loss: 1.954552
# (Epoch 2 / 10) train acc: 0.332000; val_acc: 0.334000
# (Iteration 501 / 2450) loss: 1.937707
# (Iteration 601 / 2450) loss: 1.852065
# (Iteration 701 / 2450) loss: 1.890704
# (Epoch 3 / 10) train acc: 0.386000; val_acc: 0.363000
# (Iteration 801 / 2450) loss: 1.812634
# (Iteration 901 / 2450) loss: 1.873806
# (Epoch 4 / 10) train acc: 0.368000; val_acc: 0.384000
# (Iteration 1001 / 2450) loss: 1.743740
# (Iteration 1101 / 2450) loss: 1.678230
# (Iteration 1201 / 2450) loss: 1.652566
# (Epoch 5 / 10) train acc: 0.411000; val_acc: 0.401000
# (Iteration 1301 / 2450) loss: 1.715484
# (Iteration 1401 / 2450) loss: 1.748810
# (Epoch 6 / 10) train acc: 0.380000; val_acc: 0.408000
# (Iteration 1501 / 2450) loss: 1.646055
# (Iteration 1601 / 2450) loss: 1.641873
# (Iteration 1701 / 2450) loss: 1.691246
# (Epoch 7 / 10) train acc: 0.413000; val_acc: 0.421000
# (Iteration 1801 / 2450) loss: 1.673374
# (Iteration 1901 / 2450) loss: 1.547261
# (Epoch 8 / 10) train acc: 0.417000; val_acc: 0.427000
# (Iteration 2001 / 2450) loss: 1.555505
# (Iteration 2101 / 2450) loss: 1.625150
# (Iteration 2201 / 2450) loss: 1.537480
# (Epoch 9 / 10) train acc: 0.394000; val_acc: 0.442000
# (Iteration 2301 / 2450) loss: 1.679774
# (Iteration 2401 / 2450) loss: 1.566347
# (Epoch 10 / 10) train acc: 0.423000; val_acc: 0.438000
# ----------------------------learning_rate: 0.0001, hidden_dim: 200, epoch_num: 15------------------------------
# (Iteration 1 / 3675) loss: 2.300300
# (Epoch 0 / 15) train acc: 0.122000; val_acc: 0.114000
# (Iteration 101 / 3675) loss: 2.183518
# (Iteration 201 / 3675) loss: 2.090280
# (Epoch 1 / 15) train acc: 0.290000; val_acc: 0.288000
# (Iteration 301 / 3675) loss: 1.920633
# (Iteration 401 / 3675) loss: 1.981221
# (Epoch 2 / 15) train acc: 0.342000; val_acc: 0.323000
# (Iteration 501 / 3675) loss: 1.901171
# (Iteration 601 / 3675) loss: 1.815786
# (Iteration 701 / 3675) loss: 1.848125
# (Epoch 3 / 15) train acc: 0.327000; val_acc: 0.371000
# (Iteration 801 / 3675) loss: 1.815594
# (Iteration 901 / 3675) loss: 1.662007
# (Epoch 4 / 15) train acc: 0.373000; val_acc: 0.381000
# (Iteration 1001 / 3675) loss: 1.743605
# (Iteration 1101 / 3675) loss: 1.739638
# (Iteration 1201 / 3675) loss: 1.734262
# (Epoch 5 / 15) train acc: 0.370000; val_acc: 0.407000
# (Iteration 1301 / 3675) loss: 1.642450
# (Iteration 1401 / 3675) loss: 1.732301
# (Epoch 6 / 15) train acc: 0.419000; val_acc: 0.412000
# (Iteration 1501 / 3675) loss: 1.835011
# (Iteration 1601 / 3675) loss: 1.726896
# (Iteration 1701 / 3675) loss: 1.615040
# (Epoch 7 / 15) train acc: 0.392000; val_acc: 0.426000
# (Iteration 1801 / 3675) loss: 1.709202
# (Iteration 1901 / 3675) loss: 1.555162
# (Epoch 8 / 15) train acc: 0.416000; val_acc: 0.439000
# (Iteration 2001 / 3675) loss: 1.650127
# (Iteration 2101 / 3675) loss: 1.633393
# (Iteration 2201 / 3675) loss: 1.599986
# (Epoch 9 / 15) train acc: 0.440000; val_acc: 0.447000
# (Iteration 2301 / 3675) loss: 1.601361
# (Iteration 2401 / 3675) loss: 1.661928
# (Epoch 10 / 15) train acc: 0.437000; val_acc: 0.451000
# (Iteration 2501 / 3675) loss: 1.559767
# (Iteration 2601 / 3675) loss: 1.551104
# (Epoch 11 / 15) train acc: 0.445000; val_acc: 0.450000
# (Iteration 2701 / 3675) loss: 1.679252
# (Iteration 2801 / 3675) loss: 1.540884
# (Iteration 2901 / 3675) loss: 1.659974
# (Epoch 12 / 15) train acc: 0.455000; val_acc: 0.455000
# (Iteration 3001 / 3675) loss: 1.636744
# (Iteration 3101 / 3675) loss: 1.561854
# (Epoch 13 / 15) train acc: 0.464000; val_acc: 0.458000
# (Iteration 3201 / 3675) loss: 1.489326
# (Iteration 3301 / 3675) loss: 1.625414
# (Iteration 3401 / 3675) loss: 1.611488
# (Epoch 14 / 15) train acc: 0.445000; val_acc: 0.458000
# (Iteration 3501 / 3675) loss: 1.597344
# (Iteration 3601 / 3675) loss: 1.549011
# (Epoch 15 / 15) train acc: 0.458000; val_acc: 0.452000
# best_acc =  0.547

# %% [markdown]
# # Test your model!
# Run your best model on the validation and test sets. You should achieve above 48% accuracy on the validation set and the test set.

# %%
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
# Out:
# Validation set accuracy:  0.547

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Test set accuracy:  0.527

# %%
# Save best model
best_model.save("best_two_layer_net.npy")

# %% [markdown]
# ## Inline Question 2:
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# $\color{blue}{\textit Your Answer:}$
#
# $\color{blue}{\textit Your Explanation:}$
